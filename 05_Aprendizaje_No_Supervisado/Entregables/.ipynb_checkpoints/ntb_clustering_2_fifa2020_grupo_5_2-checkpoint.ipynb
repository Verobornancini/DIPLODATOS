# %% [markdown]
# <center>
# <img src="FIFA-19-Background-1-768x401.jpg" />
#
# ## Aprendizaje No Supervisado 2020 DiploDatos
#     Laura Alonso Alemany, Ana Georgina Flesia y Valeria Rulloni
# ## Agrupamiento con el FIFA 2019 dataset
#
# Material basado en notas de Ana Georgina Flesia bajo los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/), a su vez basado de material de [SilveMel](https://www.kaggle.com/karangadiya/fifa19/downloads/data.csv/comments) y otros.

# %% [markdown]
# **Grupo 5 Cohorte 2**
# * Patricia Loto
# * Sandra Monica Olariaga
# * Veronica Bornancini
# * María Soledad Fernandez

# %% [markdown]
# ### Indice de temas
# 1. [Inicialización del entorno](#1.-Inicialización-del-entorno)
# 2. [Preparación de los datos](#2.-Preparación-de-los-datos)
# 3. [Clustering KM](#3.-Clustering-con-Kmeans)
# 4. [Clustering MS](#4.-Clustering-con-Mean-Shift)
# 5. [Clustering KM2](#5.-Clustering-con-Kmeans-sin-arqueros)
# 6. [Clustering MS2](#6.-Clustering-con-Mean-Shift-sin-arqueros)

# %% [markdown]
# ## 1.-Inicialización-del-entorno

# %%
# Importación de librerías
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

# %%
from plotly.offline import init_notebook_mode, plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import seaborn as sns

import plotly.io as pio
pio.renderers.default = "browser"
import plotly.express as px

random_state = 10
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2.-Preparación-de-los-datos

# %% [markdown]
# * Cargamos los datos bajados de la database de [Kaggle](https://www.kaggle.com/karangadiya/fifa19) como 'data.csv'.

# %%
df=pd.read_csv("players_20.csv")

# %%
print("El número de filas del dataset es:", df.shape[0])
print("El número de columnas del dataset es:", df.shape[1])
# Out:
# El número de filas del dataset es: 18278
# El número de columnas del dataset es: 104

# %%
# Observaremos los valores de las primeras filas
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %% [markdown]
# **NOTAS:**
# * Preparamos la base para Clustering
# * Retiramos jugadores con bajo Desempeño global ("Overall")
# * Consideramos Variables de desempeño por habilidad (skills_ratings)
# * No filtramos por los primeros 10000

# %%
df_n=df[(df['overall']>70)] # mejores jugadores

skills_ratings =  ['attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing',
                  'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                  'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions',
                  'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
                  'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
                  'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle',
                  'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']

print('Cantidad de features: ', len(skills_ratings))
print('Cantidad de filas dataset filtrado: ', len(df_n))

df_skills=df_n[skills_ratings]
# Out:
# Cantidad de features:  34
# Cantidad de filas dataset filtrado:  4756

# %%
skills_ratings
# Out:
# ['attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes']

# %% [markdown]
# # 3.-Clustering-con-Kmeans
# * Es necesario definirle la cantidad de grupos/clusters (n_clusters), es un hiperparámetro del algoritmo.

# %%
from sklearn.cluster import KMeans,MeanShift
from sklearn import decomposition

# Número de clusters buscado
n_clust = 4

km = KMeans(n_clusters=n_clust, random_state=random_state)
km.fit(df_skills)

# Recuperacion de etiquetas
clusters = km.labels_
print('Etiquetas de los  Cluster: ', clusters)
print('Suma de los cuadrados de las distancias al cluster / Inertia: ', km.inertia_)
# Out:
# Etiquetas de los  Cluster:  [2 2 2 ... 1 1 3]
# Suma de los cuadrados de las distancias al cluster / Inertia:  12232963.353970323

# %% [markdown]
# **Elección de la cantidad de grupos/clusters**
# * Una forma de seleccionar la cantidad más adecuada de clusters es probar varias cantidades y usar el criterio del codo: "elbow method", utilizando una medida de ajuste que puede ser Inertia.

# %%
#Prueba: para elegir el hiperparámetro n_clusters, variando de 2 a 11 clusters
scores = [KMeans(n_clusters=i+2).fit(df_skills).inertia_ for i in range(10)]

from matplotlib import pyplot as plt
plt.plot(np.arange(2, 12), scores)
plt.xlabel('Number of clusters')
plt.ylabel("Inertia")
plt.title("Inertia of k-Means versus number of clusters")
# Out:
# Text(0.5, 1.0, 'Inertia of k-Means versus number of clusters')

# %%
# Graficamos el resultado kmedias con la cantidad de clases elegida: Visualizamos de a dos variables por vez
data=[]
bool_crack=df_n["overall"] > 85
bool_no_crack=df_n["overall"] < 86


#Eligo dos números entre 0 y  de n_skills-1
skill_1 = skills_ratings[24]
skill_2 = skills_ratings[26]

#print(len(df_skills.loc[bool_crack,skill_1]))

# Agresion 20 y posicionamiento 22
# Ball control 9 y crossing 0
# Short Passing 3 y Drivling 5
# Penalty 24 y Marcking 26
# Ball control 9 y Acceleration 10
# Heading Accuracy 2 y Standing Tacle 27
# Ballcontrol 9 y reactions 13 


kmean_clusters = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'team_position'],
                           marker=dict(
                                size=5,
                                color = clusters.astype(np.float), #set color equal to a variable
                                colorscale='Portland',
                                showscale=False)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Ckacks!!',
                      text=df_n.loc[bool_crack,'team_position'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[kmean_clusters,crack]

layout = go.Layout(title="Clustering K means ",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# <center>
# <img src="graf1.jpg" />

# %%
df_clusters=df_n.copy()
df_clusters['kmeans'] = km.labels_ #clusters
print('Kmeans encontró: ', max(km.labels_) + 1 , 'clusters, nosotros forzamos la cantidad')
# Out:
# Kmeans encontró:  4 clusters, nosotros forzamos la cantidad

# %% [markdown]
# ### EVALUACIÓN
#
# **EJERCICIO: Análisis exploratorio de los clusters, usando las clases asignadas por kmeans**

# %% [markdown]
# ### 3.1 Cantidad de observaciones por Cluster

# %%
df_clusters[['short_name','kmeans']].groupby('kmeans').agg(['count'])
# Out:
#        short_name
#             count
# kmeans
# 0             440
# 1            1712
# 2            1644
# 3             960

# %% [markdown]
# ### 3.2 Análisis descriptivo separando por Cluster

# %% [markdown]
# #### 3.2.1 Cluster 0

# %%
df_clusters.loc[(df_clusters.kmeans==0)].head()
# Este cluster 0 contiene los Arqueros, Sustitos y Reserva
# Out:
#     sofifa_id                                         player_url  \
# 3      200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 14     193080  https://sofifa.com/player/193080/david-de-gea-...
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
#
#        short_name                  long_name  age         dob  height_cm  \
# 3        J. Oblak                  Jan Oblak   26  1993-01-07        188
# 6   M. ter Stegen      Marc-André ter Stegen   27  1992-04-30        187
# 13        Alisson      Alisson Ramses Becker   26  1992-10-02        191
# 14         De Gea      David De Gea Quintana   28  1990-11-07        192
# 25        Ederson  Ederson Santana de Moraes   25  1993-08-17        188
#
#     weight_kg nationality               club  overall  potential  value_eur  \
# ...

# %%
df_clusters.loc[(df_clusters.kmeans==0)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# GK                   279
# RES                   18
# SUB                  131

# %% [markdown]
# #### 3.2.2 Cluster 1

# %%
df_clusters.loc[(df_clusters.kmeans==1)].head()
# Al parecer el cluster 1 son los Mediocampistas, Laterales, Mediocentro, algunos extremos derechos e izquierdos
# Out:
#     sofifa_id                                         player_url  \
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 15     215914  https://sofifa.com/player/215914/ngolo-kante/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 5   K. De Bruyne      Kevin De Bruyne   28  1991-06-28        181         70
# 7    V. van Dijk      Virgil van Dijk   27  1991-07-08        193         92
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 15      N. Kanté         N'Golo Kanté   28  1991-03-29        168         72
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
#
#     nationality             club  overall  potential  value_eur  wage_eur  \
# ...

# %%
df_clusters.loc[(df_clusters.kmeans==1)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                   50
# CB                     5
# CDM                   68
# CF                     2
# CM                    26
# LAM                    1
# LB                   147
# LCB                   31
# LCM                  114
# LDM                   83
# LF                     4
# LM                    31
# LS                     1
# LW                     3
# LWB                   11
# RAM                    2
# RB                   152
# RCB                   26
# RCM                  137
# RDM                   80
# RES                   93
# RF                     2
# RM                    50
# RW                     8
# RWB                   13
# ST                     3
# SUB                  539

# %% [markdown]
# #### 3.2.3 Cluster 2

# %%
df_clusters.loc[(df_clusters.kmeans==2)].head()
# Al parecer el cluster 2 son Delanteros, laterales ofensivos,
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
# 9           M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df_clusters.loc[(df_clusters.kmeans==2)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                   98
# CDM                    1
# CF                     7
# CM                     2
# LAM                   12
# LCM                   35
# LDM                    2
# LF                     7
# LM                   132
# LS                    83
# LW                    68
# LWB                    2
# RAM                   11
# RCM                   13
# RDM                    1
# RES                   90
# RF                     5
# RM                   102
# RS                    88
# RW                    61
# RWB                    1
# ST                   213
# SUB                  575

# %% [markdown]
# #### 3.2.4 Cluster 3

# %%
df_clusters.loc[(df_clusters.kmeans==3)].head()
# Al parecer el cluster 3 son Defensores, laterales defensivos
# Out:
#     sofifa_id                                         player_url  \
# 11     201024  https://sofifa.com/player/201024/kalidou-kouli...
# 16     138956  https://sofifa.com/player/138956/giorgio-chiel...
# 35     182493  https://sofifa.com/player/182493/diego-godin/2...
# 56     207865  https://sofifa.com/player/207865/marcos-aoas-c...
# 57     232363  https://sofifa.com/player/232363/milan-skrinia...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 11  K. Koulibaly    Kalidou Koulibaly   28  1991-06-20        187         89
# 16  G. Chiellini    Giorgio Chiellini   34  1984-08-14        187         85
# 35      D. Godín          Diego Godín   33  1986-02-16        187         78
# 56    Marquinhos  Marcos  Aoás Corrêa   25  1994-05-14        183         75
# 57   M. Škriniar       Milan Škriniar   24  1995-02-11        187         80
#
#    nationality                 club  overall  potential  value_eur  wage_eur  \
# ...

# %%
df_clusters.loc[(df_clusters.kmeans==3)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CB                    35
# CDM                   13
# CM                     2
# LB                    17
# LCB                  225
# LCM                    5
# LDM                   14
# LM                     2
# LWB                    1
# RB                    24
# RCB                  236
# RCM                    8
# RDM                   15
# RES                   45
# RWB                    3
# SUB                  295

# %% [markdown]
# ### 3.3 Tabla de contingencia alguna categórica vs clusters

# %%
#df_clusters.dtypes

# %%
pd.crosstab(index=df_clusters['work_rate'],columns=df_clusters['kmeans'],margins=True)
# Out:
# kmeans           0     1     2    3   All
# work_rate
# High/High        0   295   141   29   465
# High/Low         0    32   206    2   240
# High/Medium      0   468   580   71  1119
# Low/High         0    26     0   97   123
# Low/Medium       0    19     1   78    98
# Medium/High      0   268    29  298   595
# Medium/Low       0    14   228    1   243
# Medium/Medium  440   590   459  384  1873
# All            440  1712  1644  960  4756

# %%
pd.crosstab(index=df_clusters['team_position'],columns=df_clusters['kmeans'],margins=True)
# Out:
# kmeans           0     1     2    3   All
# team_position
# CAM              0    50    98    0   148
# CB               0     5     0   35    40
# CDM              0    68     1   13    82
# CF               0     2     7    0     9
# CM               0    26     2    2    30
# GK             279     0     0    0   279
# LAM              0     1    12    0    13
# LB               0   147     0   17   164
# LCB              0    31     0  225   256
# LCM              0   114    35    5   154
# LDM              0    83     2   14    99
# LF               0     4     7    0    11
# LM               0    31   132    2   165
# LS               0     1    83    0    84
# LW               0     3    68    0    71
# LWB              0    11     2    1    14
# RAM              0     2    11    0    13
# RB               0   152     0   24   176
# RCB              0    26     0  236   262
# RCM              0   137    13    8   158
# RDM              0    80     1   15    96
# ...

# %% [markdown]
# Podemos analizar que en ambas tablas cruzadas el cluster 0 (cero) es el que tiene menor población de casos

# %% [markdown]
# ### 3.4 Silohuette Analisys

# %% [markdown]
# El análisis de silueta se puede utilizar para estudiar la distancia de separación entre los grupos resultantes. El gráfico de silueta muestra una medida de qué tan cerca está cada punto en un grupo de puntos en los grupos vecinos y, por lo tanto, proporciona una forma de evaluar parámetros como el número de grupos visualmente

# %% [markdown]
# Los coeficientes de silueta (como se denominan estos valores) cercanos a +1 indican que la muestra está lejos de los conglomerados vecinos. Un valor de 0 indica que la muestra está en o muy cerca del límite de decisión entre dos conglomerados vecinos y los valores negativos indican que esas muestras podrían haber sido asignadas al conglomerado incorrecto.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

range_n_clusters = [2,3,4,5,6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 
    ax1.set_xlim([-1, 1])
    
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    
    ax1.set_ylim([0, len(df_skills) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(df_skills)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed clusters
    silhouette_avg = silhouette_score(df_skills, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(df_skills, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(df_skills.iloc[:, 0], df_skills.iloc[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6252707111708773
# For n_clusters = 3 The average silhouette_score is : 0.35731495331826296
# For n_clusters = 4 The average silhouette_score is : 0.3285163575048322
# For n_clusters = 5 The average silhouette_score is : 0.2855927333388514
# For n_clusters = 6 The average silhouette_score is : 0.23410740465682306

# %% [markdown]
# Si bien el coeficiente con 2 clusters evidencia dos grupos bastante divisibles, visualmente podemos decir que 4 clusters es la mejor opción porque cumple las condiciones de ser mayores a la media y la cantidad de casos por cluster es más heterogenea ?????

# %% [markdown]
# # 4.-Clustering-Mean-Shift
#
# - NO es necesario definirle la cantidad de grupos/clusters
# - NO es escalable, computacionalmente es muy pesado. Cada dato tienen un proceso iterativo en donde en cada iteración considera los vecinos a menos de un radio de distancia.
# - Hipeparámetros: radio (de cobertura para cálculo de media)

# %%
### from sklearn.cluster import KMeans,MeanShift
from sklearn import decomposition

#ms = MeanShift(bandwidth=35, bin_seeding=True) # Encuentra dos cluster pero queda particionado uno de los cluster en la grafica
ms = MeanShift() # Encuentra dos cluster pero uno mucho más grande que otro

ms.fit(df_skills)

clusters2 = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(clusters2)
n_clusters_ = len(labels_unique)

print("Numero estimado de clusters para Mean Shift : %d" % n_clusters_)

# Etquetas de los elementos de los clusters
# Out:
# Numero estimado de clusters para Mean Shift : 2

# %% [markdown]
# Según *mean shift* el número adecuado de clusters sería **2**

# %%
data=[]
bool_crack=df_n["overall"] > 85
bool_no_crack=df_n["overall"] < 86


#Eligo dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[24]
skill_2=skills_ratings[26]


MeanShift_clusters = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'work_rate'],
                           marker=dict(
                                size=5,
                                color = clusters2.astype(np.float), #set color equal to a variable
                                colorscale='Portland',
                                showscale=False)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Top players',
                      text=df_n.loc[bool_crack,'work_rate'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[MeanShift_clusters,crack]

layout = go.Layout(title="Mean Shift",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# <center>
# <img src="graf2.jpg" />

# %%
df_clusters['MeanShift'] = ms.labels_ #clusters2
print('Kmeans encontró: ', max(km.labels_) + 1, 'clusters, nosotros lo forzamos')
print('Mean shift encontró ', max(ms.labels_) + 1, 'clusters, según los hiperparámetros elegidos')
# Out:
# Kmeans encontró:  4 clusters, nosotros lo forzamos
# Mean shift encontró  2 clusters, según los hiperparámetros elegidos

# %% [markdown]
# ### EVALUACIÓN
#
# **EJERCICIO EN GRUPO: Análisis exploratorio de los clusters, usando las clases asignadas por MeanShift**

# %% [markdown]
# ### 4.1 Cantidad de observaciones por Cluster

# %%
df_clusters[['short_name','MeanShift']].groupby('MeanShift').agg(['count'])
# Out:
#           short_name
#                count
# MeanShift
# 0               4316
# 1                440

# %% [markdown]
# ### 4.2 Análisis descriptivo separando por Cluster

# %% [markdown]
# #### 4.2.1 Cluster 0

# %%
df_clusters.loc[(df_clusters.MeanShift==0)].head()
# Al parecer el cluster 0 son todas las Posiciones menos los Arqueros
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                      Kevin De Bruyne   28  1991-06-28
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df_clusters.loc[(df_clusters.MeanShift==0)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                  148
# CB                    40
# CDM                   82
# CF                     9
# CM                    30
# LAM                   13
# LB                   164
# LCB                  256
# LCM                  154
# LDM                   99
# LF                    11
# LM                   165
# LS                    84
# LW                    71
# LWB                   14
# RAM                   13
# RB                   176
# RCB                  262
# RCM                  158
# RDM                   96
# RES                  228
# RF                     7
# RM                   152
# RS                    88
# RW                    69
# RWB                   17
# ST                   216
# SUB                 1409

# %% [markdown]
# #### 4.2.2 Cluster 1

# %%
df_clusters.loc[(df_clusters.MeanShift==1)].head()
# Al parecer el cluster 1 son Arqueros, reserva y sustitutos en su mayoria
# Out:
#     sofifa_id                                         player_url  \
# 3      200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 14     193080  https://sofifa.com/player/193080/david-de-gea-...
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
#
#        short_name                  long_name  age         dob  height_cm  \
# 3        J. Oblak                  Jan Oblak   26  1993-01-07        188
# 6   M. ter Stegen      Marc-André ter Stegen   27  1992-04-30        187
# 13        Alisson      Alisson Ramses Becker   26  1992-10-02        191
# 14         De Gea      David De Gea Quintana   28  1990-11-07        192
# 25        Ederson  Ederson Santana de Moraes   25  1993-08-17        188
#
#     weight_kg nationality               club  overall  potential  value_eur  \
# ...

# %%
df_clusters.loc[(df_clusters.MeanShift==1)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# GK                   279
# RES                   18
# SUB                  131

# %% [markdown]
# ### 4.3 Tabla de contingencia alguna categórica vs clusters

# %%
pd.crosstab(index=df_clusters['work_rate'],columns=df_clusters['MeanShift'],margins=True)
# Out:
# MeanShift         0    1   All
# work_rate
# High/High       465    0   465
# High/Low        240    0   240
# High/Medium    1119    0  1119
# Low/High        123    0   123
# Low/Medium       98    0    98
# Medium/High     595    0   595
# Medium/Low      243    0   243
# Medium/Medium  1433  440  1873
# All            4316  440  4756

# %%
pd.crosstab(index=df_clusters['preferred_foot'],columns=df_clusters['MeanShift'],margins=True)
# Out:
# MeanShift          0    1   All
# preferred_foot
# Left            1105   60  1165
# Right           3211  380  3591
# All             4316  440  4756

# %% [markdown]
# Al igual que el análisis de cross tab anterior el cluster 1 tienen muchos menos casos en comparación al cluster 0

# %% [markdown]
# ### 4.4 Graficamos Mean Shift

# %%
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

labels_true = df_skills.iloc[:,0]
X = StandardScaler().fit_transform(df_skills)

print('Estimated number of clusters: %d' % n_clusters_)
#print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true,clusters2))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true,clusters2))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true,clusters2))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, clusters2))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true,clusters2,
                                           average_method='arithmetic'))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, clusters2))


# Black removed and is used for noise instead.
unique_labels = set(clusters2)
colors = [plt.cm.autumn(each)
          for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (clusters2 == k)
    cluster_center = cluster_centers[k]

    xy = df_skills[class_member_mask]
    plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
    
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 2
# Homogeneity: 0.070
# Completeness: 0.924
# V-measure: 0.130
# Adjusted Rand Index: 0.009
# Adjusted Mutual Information: 0.127
# Silhouette Coefficient: 0.596

# %% [markdown]
# **Pregunta: normalizamos/estandarizamos la base?**

# %% [markdown]
# Digamos que la normalizacion es el primer paso de la estandarizacion. A continuación se describe una lógica general de análisis, pero tenemos que tener en cuenta que no es aplicable en todos los casos

# %% [markdown]
# #### Normalizamos
# 1. La normalización hace que el entrenamiento sea menos sensible a la escala de características, por lo que podemos resolver mejor los coeficientes.
# 2. El uso de un método de normalización mejorará el análisis de múltiples modelos.
# 3. La normalización asegurará que un problema de convergencia no tenga una varianza masiva, haciendo factible la optimización.

# %% [markdown]
# #### Estandarizamos
# 1. Compare características que tengan diferentes unidades o escalas.
# 2. La estandarización tiende a hacer que el proceso de entrenamiento se comporte bien porque se mejora la condición numérica de los problemas de optimización.

# %% [markdown]
# Para que funcionen mejor muchos algoritmos de Machine Learning usados en Data Science, hay que normalizar las variables de entrada al algoritmo. Normalizar significa, en este caso, comprimir o extender los valores de la variable para que estén en un rango definido. Sin embargo, una mala aplicación de la normalización, o una elección descuidada del método de normalización puede arruinar tus datos, y con ello tu análisis.
# En este caso podemos NORMALIZAR las features numericas

# %% [markdown]
# **Ahora vemos que agrupamientos podemos hacer excluyendo los arqueros**

# %% [markdown]
# # 5.-Clustering-con-Kmeans-sin-arqueros

# %%
#n=10000

#df_n=df.loc[:n]
#df_n=df_n[(df_n["Position"] != 'GK')&(df_n['Overall'] > 69)]

df_n_sa=df[(df["team_position"] != 'GK') & (df['overall'] > 69) & (df["player_positions"] != 'GK')]

skills_ratings =  ['attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing',
                  'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                  'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions',
                  'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
                  'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
                  'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle',
                  ]

df_skills_sa=df_n_sa[skills_ratings]

print('Cantidad de filas del dataset sin Arqueros con un Overall mayor a 69: ', len(df_skills_sa))
# Out:
# Cantidad de filas del dataset sin Arqueros con un Overall mayor a 69:  5137

# %%
print('Cantidad de Filas data set sin arqueros:', len(df_n_sa))
df_n_sa[['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
# Cantidad de Filas data set sin arqueros: 5137
#               short_name
#                    count
# team_position
# CAM                  169
# CB                    41
# CDM                   94
# CF                    10
# CM                    37
# LAM                   15
# LB                   205
# LCB                  298
# LCM                  188
# LDM                  117
# LF                    11
# LM                   190
# LS                    96
# LW                    77
# LWB                   17
# RAM                   14
# RB                   223
# RCB                  309
# RCM                  191
# RDM                  109
# RES                  278
# RF                     8
# RM                   181
# RS                    98
# RW                    84
# RWB                   18
# ST                   248
# SUB                 1708

# %%
from sklearn import preprocessing

x = df_skills_sa.values #returns a numpy array
x_normalize = preprocessing.normalize(x)

std_scaler = preprocessing.StandardScaler()
x_scaled = std_scaler.fit_transform(x_normalize)
df_skills_sa_scaled = pd.DataFrame(x_scaled)

df_skills_sa_scaled.columns = ['attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing',
                  'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                  'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions',
                  'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
                  'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
                  'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle',
                  ]

# %%
len(df_skills_sa_scaled)
# Out:
# 5137

# %%
df_skills_sa_scaled
# Out:
#       attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0               0.774883             1.248433                   -0.569164
# 1               0.573384             1.260250                    0.616551
# 2               0.943554             1.009425                   -0.895853
# 3               0.548111             0.875398                   -0.933224
# 4               1.235517             0.643986                   -1.394325
# ...                  ...                  ...                         ...
# 5132           -1.297567            -0.275139                   -0.051979
# 5133            1.018271             0.502567                   -1.045392
# 5134            0.370100             0.645217                   -0.774145
# 5135           -0.060302            -0.324427                   -1.227364
# 5136            0.816428             0.195461                   -1.016523
#
#       attacking_short_passing  attacking_volleys  skill_dribbling  \
# ...

# %%
from sklearn.cluster import KMeans,MeanShift
from sklearn import decomposition

# Vamos a normalizar los datos

# Número de clusters buscado
n_clust = 5

km = KMeans(n_clusters=n_clust)
km.fit(df_skills_sa_scaled)

# Recuperacion de etiquetas
clusters = km.labels_

data=[]
bool_crack_sa=df_n_sa["overall"] > 85
bool_no_crack_sa=df_n_sa["overall"] < 86

#print(len(df_n_sa))
#print(len(df_skills_sa_scaled))
#print(len(bool_crack))

#print(bool_crack.head)

# %%
#Prueba: para elegir el hiperparámetro n_clusters, variando de 2 a 11 clusters
scores = [KMeans(n_clusters=i+2).fit(df_skills_sa_scaled).inertia_ for i in range(10)]

from matplotlib import pyplot as plt
plt.plot(np.arange(2, 12), scores)
plt.xlabel('Number of clusters')
plt.ylabel("Inertia")
plt.title("Inertia of k-Means versus number of clusters")
# Out:
# Text(0.5, 1.0, 'Inertia of k-Means versus number of clusters')

# %%
#Eligo dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[5] # 24, 5 
skill_2=skills_ratings[15] # 26, 15

#print(skill_1)
#print(skill_2)


kmean_clusters = go.Scatter(x=df_skills_sa_scaled[skill_1], y=df_skills_sa_scaled[skill_2],
                           mode='markers',
                           text=df_n_sa.loc[:,'team_position'],#text=df_n_sa.loc[:,'nationality'], #text=df_n_sa.loc[:,'player_positions'],
                           marker=dict(
                                size=5,
                                color = clusters.astype(np.float), #set color equal to a variable
                                colorscale='Portland',
                                showscale=False)
                           )

#crack = go.Scatter(x=df_skills_sa_scaled.loc[bool_crack_sa,skill_1], y=df_skills_sa_scaled.loc[bool_crack_sa,skill_2],name='Top players',
#                      text=df_n_sa.loc[:,'team_position'],#text=df_n_sa.loc[bool_crack,'nationality'],
#                      textfont=dict(family='sans serif',size=10,color='black'),
#                      opacity=0.9,mode='text')
#Esto no me funciona

#data=[kmean_clusters,crack] #Esto no me funciona

data=[kmean_clusters]

layout = go.Layout(title="Clustering K means ",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# <center>
# <img src="graf3.jpg" />

# %%
range_n_clusters = [2,3,4,5,6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 
    ax1.set_xlim([-1, 1])
    
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    
    ax1.set_ylim([0, len(df_skills_sa_scaled) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(df_skills_sa_scaled)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed clusters
    silhouette_avg = silhouette_score(df_skills_sa_scaled, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(df_skills_sa_scaled, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(df_skills_sa_scaled.iloc[:, 0], df_skills_sa_scaled.iloc[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2438391429050463
# For n_clusters = 3 The average silhouette_score is : 0.19994747986285308
# For n_clusters = 4 The average silhouette_score is : 0.18577782636309909
# For n_clusters = 5 The average silhouette_score is : 0.15098647963544615
# For n_clusters = 6 The average silhouette_score is : 0.14077005676079923

# %% [markdown]
# Trabajando con las features escaladas o normalizadas podemos ver 5 clusters aunque el coeficiente nos indica que la frontera entre ellos es muy difusa. Chequeamos que es cada cluster

# %%
df_clusters_esc=df_n_sa.copy()
df_clusters_esc['kmeans'] = km.labels_ #clusters

# %% [markdown]
# #### Cantidad de Casos por Cluster para Kmeans

# %%
df_clusters_esc[['short_name','kmeans']].groupby('kmeans').agg(['count'])
# Out:
#        short_name
#             count
# kmeans
# 0            1143
# 1             777
# 2            1109
# 3             874
# 4            1234

# %%
df_clusters_esc[['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                  169
# CB                    41
# CDM                   94
# CF                    10
# CM                    37
# LAM                   15
# LB                   205
# LCB                  298
# LCM                  188
# LDM                  117
# LF                    11
# LM                   190
# LS                    96
# LW                    77
# LWB                   17
# RAM                   14
# RB                   223
# RCB                  309
# RCM                  191
# RDM                  109
# RES                  278
# RF                     8
# RM                   181
# RS                    98
# RW                    84
# RWB                   18
# ST                   248
# SUB                 1708

# %% [markdown]
# Al tener los valores normalizados/estandarizados de los cluster son un poco más homogeneos en cantidad de los anteriormente vistos.

# %% [markdown]
# #### Cluster 0

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==0)].head()
# Al parecer el cluster 0 son Mediocampistas, laterales, centrales
# Out:
#     sofifa_id                                         player_url  \
# 15     215914  https://sofifa.com/player/215914/ngolo-kante/2...
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 82     216267  https://sofifa.com/player/216267/andrew-robert...
# 94     204963  https://sofifa.com/player/204963/daniel-carvaj...
# 99     170890  https://sofifa.com/player/170890/blaise-matuid...
#
#       short_name              long_name  age         dob  height_cm  \
# 15      N. Kanté           N'Golo Kanté   28  1991-03-29        168
# 51    Jordi Alba       Jordi Alba Ramos   30  1989-03-21        170
# 82  A. Robertson       Andrew Robertson   25  1994-03-11        178
# 94      Carvajal  Daniel Carvajal Ramos   27  1992-01-11        173
# 99    B. Matuidi         Blaise Matuidi   32  1987-04-09        180
#
#     weight_kg nationality          club  overall  potential  value_eur  \
# 15         72      France       Chelsea       89         90   66000000
# ...

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==0)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                    6
# CB                     3
# CDM                   29
# CF                     1
# CM                     3
# LB                   174
# LCB                   47
# LCM                   30
# LDM                   31
# LM                    19
# LWB                   11
# RB                   191
# RCB                   33
# RCM                   44
# RDM                   33
# RES                   53
# RM                    19
# RS                     1
# RW                     7
# RWB                   16
# SUB                  372

# %% [markdown]
# #### Cluster 1

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==1)].head()
# Al parecer el cluster 1 son delatentero, laterales atacantes
# Out:
#     sofifa_id                                         player_url  \
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 12     202126  https://sofifa.com/player/202126/harry-kane/20...
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 20     188545  https://sofifa.com/player/188545/robert-lewand...
#
#            short_name                            long_name  age         dob  \
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 12            H. Kane                           Harry Kane   25  1993-07-28
# 17          S. Agüero    Sergio Leonel Agüero del Castillo   31  1988-06-02
# 19          L. Suárez             Luis Alberto Suárez Díaz   32  1987-01-24
# 20     R. Lewandowski                   Robert Lewandowski   30  1988-08-21
#
#     height_cm  weight_kg nationality               club  overall  potential  \
# ...

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==1)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                    8
# CF                     4
# LAM                    1
# LF                     1
# LM                    14
# LS                    72
# LW                     6
# RCM                    1
# RES                   39
# RM                    16
# RS                    65
# RW                     9
# ST                   227
# SUB                  295

# %% [markdown]
# #### Cluster 2

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==2)].head()
# Al parecer el cluster 2 son defensores, laterales defensores
# Out:
#     sofifa_id                                         player_url  \
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 24     195864  https://sofifa.com/player/195864/paul-pogba/20...
#
#          short_name                 long_name  age         dob  height_cm  \
# 5      K. De Bruyne           Kevin De Bruyne   28  1991-06-28        181
# 8         L. Modrić               Luka Modrić   33  1985-09-09        172
# 18     Sergio Ramos       Sergio Ramos García   33  1986-03-30        184
# 21  Sergio Busquets  Sergio Busquets i Burgos   30  1988-07-16        189
# 24         P. Pogba                Paul Pogba   26  1993-03-15        191
#
#     weight_kg nationality               club  overall  potential  value_eur  \
# ...

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==2)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                   47
# CB                     5
# CDM                   59
# CF                     1
# CM                    29
# LAM                    2
# LB                    28
# LCB                   29
# LCM                  116
# LDM                   75
# LF                     2
# LM                    16
# LW                     4
# LWB                    3
# RAM                    3
# RB                    27
# RCB                   15
# RCM                  120
# RDM                   65
# RES                   70
# RF                     1
# RM                    24
# RW                     2
# RWB                    1
# ST                     5
# SUB                  345

# %% [markdown]
# #### Cluster 3

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==3)].head()
# Al parecer el cluster 3 son delanteros
# Out:
#     sofifa_id                                         player_url  \
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 11     201024  https://sofifa.com/player/201024/kalidou-kouli...
# 16     138956  https://sofifa.com/player/138956/giorgio-chiel...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 35     182493  https://sofifa.com/player/182493/diego-godin/2...
#
#       short_name              long_name  age         dob  height_cm  \
# 7    V. van Dijk        Virgil van Dijk   27  1991-07-08        193
# 11  K. Koulibaly      Kalidou Koulibaly   28  1991-06-20        187
# 16  G. Chiellini      Giorgio Chiellini   34  1984-08-14        187
# 29         Piqué  Gerard Piqué Bernabéu   32  1987-02-02        194
# 35      D. Godín            Diego Godín   33  1986-02-16        187
#
#     weight_kg  nationality          club  overall  potential  value_eur  \
# 7          92  Netherlands     Liverpool       90         91   78000000
# ...

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==3)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CB                    33
# CDM                    5
# CM                     1
# LB                     3
# LCB                  222
# LCM                    1
# LDM                    7
# RB                     4
# RCB                  261
# RCM                    2
# RDM                   10
# RES                   43
# SUB                  258

# %% [markdown]
# #### Cluster 4

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==4)].head()
# Al parecer el cluster 4 son delanteros mediocampistas
# Out:
#     sofifa_id                                         player_url short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...  Neymar Jr
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  E. Hazard
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...   M. Salah
# 10     231747  https://sofifa.com/player/231747/kylian-mbappe...  K. Mbappé
#
#                          long_name  age         dob  height_cm  weight_kg  \
# 0   Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 2    Neymar da Silva Santos Junior   27  1992-02-05        175         68
# 4                      Eden Hazard   28  1991-01-07        175         74
# 9             Mohamed  Salah Ghaly   27  1992-06-15        175         71
# 10                   Kylian Mbappé   20  1998-12-20        178         73
#
# ...

# %%
df_clusters_esc.loc[(df_clusters_esc.kmeans==4)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                  108
# CDM                    1
# CF                     4
# CM                     4
# LAM                   12
# LCM                   41
# LDM                    4
# LF                     8
# LM                   141
# LS                    24
# LW                    67
# LWB                    3
# RAM                   11
# RB                     1
# RCM                   24
# RDM                    1
# RES                   73
# RF                     7
# RM                   122
# RS                    32
# RW                    66
# RWB                    1
# ST                    16
# SUB                  438

# %% [markdown]
# # 6.-Clustering-Mean-Shift-sin-arqueros

# %%
from sklearn.cluster import KMeans,MeanShift
from sklearn import decomposition


#ms = MeanShift(bandwidth=5, bin_seeding=True)#, seeds=[1,2,3])
ms = MeanShift()

ms.fit(df_skills_sa_scaled)

clusters2 = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(clusters2)
n_clusters_ = len(labels_unique)

print("Numero de clusters encontrado por Mean Shift : %d" % n_clusters_)
# Out:
# Numero de clusters encontrado por Mean Shift : 5

# %% [markdown]
# Por mas que variamos el bandwith este tipo de clusterizacion solo encuentra un cluster, por ello utilizaremos la parametrizacion por defecto del modelo, dicha parametrizacion encuentra la misma cantidad de cluster que el modelo K Means empleado anteriormente

# %%
data=[]
bool_crack_sa=df_n_sa["overall"] > 85
bool_no_crack_sa=df_n_sa["overall"] < 86


#Eligo dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[9]
skill_2=skills_ratings[10]


MeanShift_clusters = go.Scatter(x=df_skills_sa_scaled[skill_1], y=df_skills_sa_scaled[skill_2],
                           mode='markers',
                        text=df_n_sa.loc[:,'team_position'],
                           marker=dict(
                                size=5,
                                color = clusters2.astype(np.float), #set color equal to a variable
                                colorscale='Portland',
                                showscale=False)
                           )

#crack =go.Scatter(x=df_skills_sa_scaled.loc[bool_crack_sa,skill_1], y=df_skills_sa_scaled.loc[bool_crack_sa,skill_2],name='Top players',
#                      text=df_n_sa.loc[bool_crack_sa,'team_position'],
#                      textfont=dict(family='sans serif',size=10,color='black'),
#                      opacity=0.9,mode='text')

#data=[MeanShift_clusters,crack]

data=[MeanShift_clusters]

layout = go.Layout(title="Mean Shift",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# <center>
# <img src="graf4.jpg" />

# %%
#df_clusters_sa=df_skills_sa
df_clusters_sa=df_n_sa.copy()
df_clusters_sa['kmeans'] = km.labels_ #clusters
df_clusters_sa['MeanShift'] = ms.labels_ #clusters2
df_clusters_sa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                      Kevin De Bruyne   28  1991-06-28
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %% [markdown]
# ### Cantidad de Casos por Cluster en MeanShift

# %%
df_clusters_sa[['short_name','MeanShift']].groupby('MeanShift').agg(['count'])
# Out:
#           short_name
#                count
# MeanShift
# 0               4738
# 1                 27
# 2                113
# 3                192
# 4                 67

# %% [markdown]
# La mayoría de los casos con este modelo caen el el cluster 0

# %% [markdown]
# **Análisis exploratorio de las clases**

# %% [markdown]
# #### Cluster 0

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==0)].head()
# Al parecer el cluster 0 son Delanteros, mediocampistas de ataque, laterales de ataque
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                      Kevin De Bruyne   28  1991-06-28
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==0)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Out:
#               short_name
#                    count
# team_position
# CAM                  169
# CB                    26
# CDM                   94
# CF                    10
# CM                    37
# LAM                   15
# LB                   204
# LCB                  195
# LCM                  188
# LDM                  116
# LF                    11
# LM                   190
# LS                    96
# LW                    77
# LWB                   17
# RAM                   14
# RB                   223
# RCB                  188
# RCM                  190
# RDM                  106
# RES                  255
# RF                     8
# RM                   181
# RS                    98
# RW                    84
# RWB                   18
# ST                   248
# SUB                 1584

# %% [markdown]
# #### Cluster 1

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==1)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Al parecer el cluster 0 son Defensores
# Out:
#               short_name
#                    count
# team_position
# LCB                   12
# RCB                    6
# RES                    2
# SUB                    6

# %% [markdown]
# #### Cluster 2

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==2)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Al parecer el cluster 0 son mediocampistas y laterales
# Out:
#               short_name
#                    count
# team_position
# CB                     4
# LCB                   27
# RCB                   32
# RDM                    1
# RES                    8
# SUB                   37

# %% [markdown]
# #### Cluster 3

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==3)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Al parecer el cluster 0 son mediocampistas, defensores y laterales
# Out:
#               short_name
#                    count
# team_position
# CB                     8
# LB                     1
# LCB                   47
# RCB                   62
# RCM                    1
# RES                    9
# SUB                   62

# %% [markdown]
# #### Cluster 4

# %%
df_clusters_sa.loc[(df_clusters_sa.MeanShift==4)][['short_name','team_position']].groupby('team_position').agg(['count'])
# Al parecer el cluster 0 son mediocampistas, defensores y laterales
# Out:
#               short_name
#                    count
# team_position
# CB                     3
# LCB                   17
# LDM                    1
# RCB                   21
# RDM                    2
# RES                    4
# SUB                   19

# %%
from sklearn import metrics
#from sklearn.preprocessing import StandardScaler

labels_true = df_skills_sa_scaled.iloc[:,0]
X = df_skills_sa_scaled


print('Estimated number of clusters: %d' % n_clusters_)
#print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true,clusters2))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true,clusters2))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true,clusters2))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, clusters2))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true,clusters2,
                                           average_method='arithmetic'))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, clusters2))


# Black removed and is used for noise instead.
unique_labels = set(clusters2)
colors = [plt.cm.autumn(each)
          for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (clusters2 == k)
    cluster_center = cluster_centers[k]

    xy = df_skills_sa_scaled[class_member_mask]
    plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
    
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 5
# Homogeneity: 0.043
# Completeness: 1.000
# V-measure: 0.082
# Adjusted Rand Index: 0.000
# Adjusted Mutual Information: 0.000
# Silhouette Coefficient: 0.248
